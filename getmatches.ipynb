# %%
import pandas as pd, requests

# %%
#get TI matches
ti_matches = requests.get('https://api.opendota.com/api/leagues/14268/matches')
ti_matches = ti_matches.json()

# %%
#load all ti matches
matches_df = pd.DataFrame(ti_matches)
matches_df.head()
# Out:
#      match_id  match_seq_num  radiant_win  start_time  duration  \
# 0  6819203954     5710904676        False  1666529028      3059
# 1  6819093598     5710780793        False  1666525260      2145
# 2  6818958825     5710689424         True  1666519940      3450
# 3  6818876789     5710587268        False  1666516003      2504
# 4  6818781180     5710510511        False  1666511449      2541
#
#    tower_status_radiant  tower_status_dire  barracks_status_radiant  \
# 0                   262                516                       51
# 1                  1796               2038                       51
# 2                  1536                260                        0
# 3                   516               1588                       15
# 4                  1072               1972                       12
#
#    barracks_status_dire  cluster  ...  \
# 0                     3      154  ...
# 1                    63      154  ...
# 2                    51      154  ...
# 3                    63      154  ...
# 4                    63      154  ...
#
#                                     radiant_gold_adv  \
# 0  [0, -487, -446, -600, -693, -1270, -1515, -132...
# 1  [0, 171, 317, 147, 531, 245, 711, 741, 833, -4...
# 2  [0, 314, 133, 256, 644, 1337, 1218, 1484, 1722...
# 3  [0, -150, -270, -223, -354, -467, -821, -672, ...
# 4  [0, 9, -70, -128, -731, -159, -447, -63, -29, ...
#
#                                       radiant_xp_adv  \
# 0  [0, -146, -133, -121, 88, -807, -1318, -764, -...
# 1  [0, 254, 249, -64, 133, -338, -408, -200, -520...
# 2  [0, -11, -80, 238, 640, 1249, 674, 1136, 1333,...
# 3  [0, -172, -61, -331, -195, -755, -832, -586, -...
# 4  [0, 33, 73, 136, -432, -79, -523, 137, 709, 79...
#
#                                           teamfights  version  \
# 0  [{'start': 1040, 'end': 1088, 'last_death': 10...       21
# 1  [{'start': 476, 'end': 540, 'last_death': 525,...       21
# 2  [{'start': 551, 'end': 597, 'last_death': 582,...       21
# 3  [{'start': 1141, 'end': 1184, 'last_death': 11...       21
# 4  [{'start': 772, 'end': 827, 'last_death': 812,...       21
#
#                                            cosmetics  radiant_score  \
# 0  {'647': 2, '4990': 129, '5049': 4, '5939': 131...             48
# 1  {'647': 130, '746': 129, '5939': 131, '6480': ...             21
# 2  {'647': 129, '6463': 132, '6464': 132, '6465':...             49
# 3  {'647': 0, '4794': 129, '4998': 129, '5957': 0...             14
# 4  {'600': 2, '647': 128, '4794': 131, '4998': 13...             30
#
#    dire_score                                      draft_timings series_id  \
# 0          41  [{'order': 1, 'pick': False, 'active_team': 3,...    716345
# 1          36  [{'order': 1, 'pick': False, 'active_team': 3,...    716345
# 2          37  [{'order': 1, 'pick': False, 'active_team': 3,...    716345
# 3          28  [{'order': 1, 'pick': False, 'active_team': 3,...    716303
# 4          23  [{'order': 1, 'pick': False, 'active_team': 3,...    716303
#
#    series_type
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1
#
# [5 rows x 39 columns]

# %%
#save json file for each match if not yet saved
all_matches = list(matches_df['match_id'])
saved_matches_df = pd.read_csv('working/saved_matches.csv')
saved_matches = list(saved_matches_df['match_id'])
for match in all_matches:
    if match not in saved_matches:
        match_list = []
        match_data = requests.get(f'https://api.opendota.com/api/matches/{match}')
        match_data = match_data.json()
        match_list.append(match_data)
        match_data_df = pd.DataFrame(match_list)
        match_data_json = match_data_df.to_json(f'matches/{match}.json')
        saved_matches.append(match)
        saved_matches_df=pd.DataFrame(saved_matches,columns=['match_id'])
        saved_matches_df.to_csv('working/saved_matches.csv',index=False)

# %%
#load all matches to json file
all_matches = list(matches_df['match_id'])
all_matches_data = []
loaded_matches_df = pd.read_csv('working/loaded_matches.csv')
loaded_matches = list(loaded_matches_df['match_id'])
loaded_matches_data_df = pd.read_json('all_matches.json')
all_matches_data.append(loaded_matches_data_df)

for match in all_matches:
    if match not in loaded_matches:
        load_match = pd.read_json(f'matches/{match}.json')
        all_matches_data.append(load_match)
        loaded_matches.append(match)
        loaded_matches_df=pd.DataFrame(loaded_matches,columns=['match_id'])
        loaded_matches_df.to_csv('working/loaded_matches.csv',index=False)
        all_matches_data_df = pd.concat(all_matches_data,ignore_index=True)
        all_matches_data_df.to_json('all_matches.json',orient="records")
