# %%
import pandas as pd, requests

# %%
#get TI matches
ti_matches = requests.get('https://api.opendota.com/api/leagues/14268/matches')
ti_matches = ti_matches.json()

# %%
#load all ti matches
matches_df = pd.DataFrame(ti_matches)
matches_df.head()
# Out:
#      match_id  match_seq_num  radiant_win  start_time  duration  \
# 0  6810986033     5703498897        False  1666075050      2662
# 1  6810984589     5703498290        False  1666075019      2604
# 2  6810895741     5703407158         True  1666066369      1585
# 3  6810942576     5703452208         True  1666070925      1925
# 4  6810974000     5703478488        False  1666073824      1823
#
#    tower_status_radiant  tower_status_dire  barracks_status_radiant  \
# 0                     0               1956                        0
# 1                  1792               1972                       50
# 2                  1983               1920                       63
# 3                  1847               1952                       63
# 4                  1846               2038                       63
#
#    barracks_status_dire  cluster  ...  \
# 0                    63      154  ...
# 1                    63      154  ...
# 2                    48      154  ...
# 3                    63      154  ...
# 4                    63      154  ...
#
#                                     radiant_gold_adv  \
# 0  [0, 699, 848, 851, 1114, 1036, 835, 1386, 887,...
# 1  [0, 848, 577, 780, 746, 628, 332, 749, 908, 13...
# 2  [0, -546, -515, -235, 338, 379, 618, 1107, 687...
# 3  [0, -503, -571, 114, 77, 5, -43, -139, 298, 96...
# 4  [0, 448, 95, 146, -563, -1213, -1256, -1173, -...
#
#                                       radiant_xp_adv  \
# 0  [0, 246, 88, 68, 233, 304, 454, 1105, 691, 797...
# 1  [0, -56, 99, 43, 224, 68, -350, 372, 667, 1264...
# 2  [0, -180, -168, 111, 815, 524, 742, 1118, 928,...
# 3  [0, -102, 157, 937, 581, 263, -158, -531, 187,...
# 4  [0, 133, -204, -16, -623, -1106, -981, -210, -...
#
#                                           teamfights  version  \
# 0  [{'start': 36, 'end': 75, 'last_death': 60, 'd...       21
# 1  [{'start': 1300, 'end': 1347, 'last_death': 13...       21
# 2  [{'start': 428, 'end': 471, 'last_death': 456,...       21
# 3  [{'start': 99, 'end': 154, 'last_death': 139, ...       21
# 4  [{'start': 1047, 'end': 1092, 'last_death': 10...       21
#
#                                            cosmetics  radiant_score  \
# 0  {'647': 129, '684': 1, '5533': 1, '5534': 1, '...             47
# 1  {'647': 131, '746': 130, '6290': 2, '6595': 2,...             13
# 2  {'647': 132, '746': 1, '4764': 4, '6459': 130,...             27
# 3  {'647': 1, '6996': 129, '7576': 2, '7580': 132...             35
# 4  {'647': 128, '4895': 128, '5631': 0, '5634': 0...             11
#
#    dire_score                                      draft_timings series_id  \
# 0          38  [{'order': 1, 'pick': False, 'active_team': 3,...    714853
# 1          27  [{'order': 1, 'pick': False, 'active_team': 3,...    714852
# 2           9  [{'order': 1, 'pick': False, 'active_team': 3,...    714832
# 3          19  [{'order': 1, 'pick': False, 'active_team': 3,...    714837
# 4          26  [{'order': 1, 'pick': False, 'active_team': 3,...    714849
#
#    series_type
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1
#
# [5 rows x 39 columns]

# %%
#save json file for each match if not yet saved
all_matches = list(matches_df['match_id'])
saved_matches_df = pd.read_csv('saved_matches.csv')
saved_matches = list(saved_matches_df['match_id'])
for match in all_matches:
    if match not in saved_matches:
        match_list = []
        match_data = requests.get(f'https://api.opendota.com/api/matches/{match}')
        match_data = match_data.json()
        match_list.append(match_data)
        match_data_df = pd.DataFrame(match_list)
        match_data_json = match_data_df.to_json(f'matches/{match}.json')
        saved_matches.append(match)
        saved_matches_df=pd.DataFrame(saved_matches,columns=['match_id'])
        saved_matches_df.to_csv('saved_matches.csv',index=False)

# %%
#load all matches to json file
all_matches = list(matches_df['match_id'])
all_matches_data = []
loaded_matches_df = pd.read_csv('loaded_matches.csv')
loaded_matches = list(loaded_matches_df['match_id'])
loaded_matches_data_df = pd.read_json('all_matches.json')
all_matches_data.append(loaded_matches_data_df)

for match in all_matches:
    if match not in loaded_matches:
        load_match = pd.read_json(f'matches/{match}.json')
        all_matches_data.append(load_match)
        loaded_matches.append(match)
        loaded_matches_df=pd.DataFrame(loaded_matches,columns=['match_id'])
        loaded_matches_df.to_csv('loaded_matches.csv',index=False)
        all_matches_data_df = pd.concat(all_matches_data,ignore_index=True)
        all_matches_data_df.to_json('all_matches.json',orient="records")
